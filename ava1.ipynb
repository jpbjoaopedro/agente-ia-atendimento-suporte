# %% [markdown]
# <a href="https://colab.research.google.com/github/jpbjoaopedro/agente-ia-atendimento-suporte/blob/main/ava1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Biblioca que instala o YOLO

# %%
# !pip install ultralytics
